# %%
# %pip install SPARQLWrapper
# %pip install pyshacl
# Out:
# Requirement already satisfied: SPARQLWrapper in g:\School\Fall 2026\Ontology-Engineering\Ontology-Tradecraft\.venv\Lib\site-packages (2.0.0)
# Requirement already satisfied: rdflib>=6.1.1 in g:\School\Fall 2026\Ontology-Engineering\Ontology-Tradecraft\.venv\Lib\site-packages (from SPARQLWrapper) (7.6.0)
# Requirement already satisfied: pyparsing<4,>=2.1.0 in g:\School\Fall 2026\Ontology-Engineering\Ontology-Tradecraft\.venv\Lib\site-packages (from rdflib>=6.1.1->SPARQLWrapper) (3.3.2)
# Note: you may need to restart the kernel to use updated packages.
# Collecting pyshacl
#   Downloading pyshacl-0.40.1-py3-none-any.whl.metadata (38 kB)
# Collecting owlrl<8,>=7.6.2 (from pyshacl)
#   Downloading owlrl-7.6.2-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: packaging>=21.3 in g:\School\Fall 2026\Ontology-Engineering\Ontology-Tradecraft\.venv\Lib\site-packages (from pyshacl) (26.3)
# Collecting prettytable>=3.7.0 (from pyshacl)
#   Downloading prettytable-3.18.0-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: rdflib<8.0,>=7.3.0 in g:\School\Fall 2026\Ontology-Engineering\Ontology-Tradecraft\.venv\Lib\site-packages (from rdflib[html]<8.0,>=7.3.0->pyshacl) (7.6.0)
# Requirement already satisfied: pyparsing<4,>=2.1.0 in g:\School\Fall 2026\Ontology-Engineering\Ontology-Tradecraft\.venv\Lib\site-packages (from rdflib<8.0,>=7.3.0->rdflib[html]<8.0,>=7.3.0->pyshacl) (3.3.2)
# Collecting html5rdf<2,>=1.2 (from rdflib[html]<8.0,>=7.3.0->pyshacl)
#   Downloading html5rdf-1.2.1-py2.py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: wcwidth>=0.3.5 in g:\School\Fall 2026\Ontology-Engineering\Ontology-Tradecraft\.venv\Lib\site-packages (from prettytable>=3.7.0->pyshacl) (0.8.2)
# Downloading pyshacl-0.40.1-py3-none-any.whl (1.3 MB)
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    ---------------------------------------- 1.3/1.3 MB 7.2 MB/s  0:00:00
# Downloading owlrl-7.6.2-py3-none-any.whl (55 kB)
# Downloading html5rdf-1.2.1-py2.py3-none-any.whl (109 kB)
# Downloading prettytable-3.18.0-py3-none-any.whl (37 kB)
# Installing collected packages: prettytable, html5rdf, owlrl, pyshacl
#
#    ---------- ----------------------------- 1/4 [html5rdf]
#    ---------- ----------------------------- 1/4 [html5rdf]
#    ---------- ----------------------------- 1/4 [html5rdf]
#    ---------- ----------------------------- 1/4 [html5rdf]
#    ---------- ----------------------------- 1/4 [html5rdf]
#    -------------------- ------------------- 2/4 [owlrl]
#    -------------------- ------------------- 2/4 [owlrl]
#    ------------------------------ --------- 3/4 [pyshacl]
#    ------------------------------ --------- 3/4 [pyshacl]
#    ------------------------------ --------- 3/4 [pyshacl]
#    ------------------------------ --------- 3/4 [pyshacl]
#    ------------------------------ --------- 3/4 [pyshacl]
#    ------------------------------ --------- 3/4 [pyshacl]
#    ------------------------------ --------- 3/4 [pyshacl]
#    ------------------------------ --------- 3/4 [pyshacl]
#    ------------------------------ --------- 3/4 [pyshacl]
#    ------------------------------ --------- 3/4 [pyshacl]
#    ------------------------------ --------- 3/4 [pyshacl]
#    ---------------------------------------- 4/4 [pyshacl]
#
# Successfully installed html5rdf owlrl prettytable pyshacl
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys
print(sys.version)
# Out:
# 3.13.5 (tags/v3.13.5:6cb20a2, Jun 11 2025, 16:15:46) [MSC v.1943 64 bit (AMD64)]

# %%
import rdflib
import SPARQLWrapper
import pyshacl

print("rdflib:", rdflib.__version__)
print("SPARQLWrapper:", SPARQLWrapper.__version__)
# pyshacl has __version__ on the package, not module attribute in some versions:
try:
    import pyshacl
    print("pyshacl:", getattr(pyshacl, "__version__", "installed"))
except Exception as e:
    print("pyshacl import error:", e)
# Out:
# rdflib: 7.6.0
# SPARQLWrapper: 2.0.0
# pyshacl: 0.40.1

# %%
from pathlib import Path
import rdflib

# Look in all sensible spots:
candidates = [
    Path.cwd() / "sample.ttl",                      # projects/project-1/assignment/sample.ttl
    Path.cwd() / "notebooks" / "sample.ttl",        # projects/project-1/assignment/notebooks/sample.ttl
    Path.cwd().parent / "notebooks" / "sample.ttl", # projects/project-1/notebooks/sample.ttl
]

ttl_path = next((p for p in candidates if p.exists()), None)
if ttl_path is None:
    raise FileNotFoundError(f"sample.ttl not found in any of: {candidates}")

print(f"Using TTL at: {ttl_path}")
g = rdflib.Graph()
g.parse(str(ttl_path), format="turtle")
print("Triple count:", len(g))
# Out:
# Using TTL at: g:\School\Fall 2026\Ontology-Engineering\Ontology-Tradecraft\projects\project-1\assignment\notebooks\sample.ttl
# Triple count: 2
